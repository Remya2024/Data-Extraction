# %% [markdown]
# # **Working with Structured Data**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# ***Extracting Data From an Excel File***

# %%
df1 = pd.read_excel('/content/drive/MyDrive/Data Source/india_state_ut.xlsx')
df1.head()
# Out:
#   Administrative divisions  No. of districts  Total population  \
# 0           Andhra Pradesh                26          49577103
# 1        Arunachal Pradesh                27           1383727
# 2                    Assam                35          31205576
# 3                    Bihar                38         104099452
# 4             Chhattisgarh                33          25545198
#
#    Population per district   Type
# 0                  1906812  State
# 1                    51249  State
# 2                   891588  State
# 3                  2739459  State
# 4                   774097  State

# %%
df2 = pd.read_excel('/content/drive/MyDrive/Data Source/india_state_ut.xlsx', sheet_name="State")
df2.head()
# Out:
#        State Details Unnamed: 1 Unnamed: 2     Unnamed: 3 Unnamed: 4  \
# 0              State        ISO    Vehicle           Zone    Capital
# 1     Andhra Pradesh      IN-AP         AP       Southern  Amaravati
# 2  Arunachal Pradesh      IN-AR         AR  North-Eastern   Itanagar
# 3              Assam      IN-AS         AS  North-Eastern     Dispur
# 4              Bihar      IN-BR         BR        Eastern      Patna
#
#             Unnamed: 5  Unnamed: 6 Unnamed: 7         Unnamed: 8  \
# 0            Statehood  Population       Area  Official Language
# 1  1956-11-01 00:00:00    49506799     162975             Telugu
# 2  1987-02-20 00:00:00     1383727      83743            English
# 3  1950-01-26 00:00:00    31205576      78438     Assamese, Boro
# 4  1950-01-26 00:00:00   104099452      94163              Hindi
#
#         Unnamed: 9
# 0  Additional Info
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df2 = pd.read_excel('/content/drive/MyDrive/Data Source/india_state_ut.xlsx', sheet_name="State")
df2.head()
# Out:
#        State Details Unnamed: 1 Unnamed: 2     Unnamed: 3 Unnamed: 4  \
# 0              State        ISO    Vehicle           Zone    Capital
# 1     Andhra Pradesh      IN-AP         AP       Southern  Amaravati
# 2  Arunachal Pradesh      IN-AR         AR  North-Eastern   Itanagar
# 3              Assam      IN-AS         AS  North-Eastern     Dispur
# 4              Bihar      IN-BR         BR        Eastern      Patna
#
#             Unnamed: 5  Unnamed: 6 Unnamed: 7         Unnamed: 8  \
# 0            Statehood  Population       Area  Official Language
# 1  1956-11-01 00:00:00    49506799     162975             Telugu
# 2  1987-02-20 00:00:00     1383727      83743            English
# 3  1950-01-26 00:00:00    31205576      78438     Assamese, Boro
# 4  1950-01-26 00:00:00   104099452      94163              Hindi
#
#         Unnamed: 9
# 0  Additional Info
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df2.columns = df2.iloc[0]
df2 = df2[1:]
df2.head()
# Out:
# 0              State    ISO Vehicle           Zone    Capital  \
# 1     Andhra Pradesh  IN-AP      AP       Southern  Amaravati
# 2  Arunachal Pradesh  IN-AR      AR  North-Eastern   Itanagar
# 3              Assam  IN-AS      AS  North-Eastern     Dispur
# 4              Bihar  IN-BR      BR        Eastern      Patna
# 5       Chhattisgarh  IN-CG      CG        Central     Raipur
#
# 0            Statehood Population    Area Official Language Additional Info
# 1  1956-11-01 00:00:00   49506799  162975            Telugu             NaN
# 2  1987-02-20 00:00:00    1383727   83743           English             NaN
# 3  1950-01-26 00:00:00   31205576   78438    Assamese, Boro             NaN
# 4  1950-01-26 00:00:00  104099452   94163             Hindi             NaN
# 5  2000-11-01 00:00:00   25545198  135194             Hindi             NaN

# %%
df2 = df2.drop('Additional Info', axis=1)
df2.head()
# Out:
# 0              State    ISO Vehicle           Zone    Capital  \
# 1     Andhra Pradesh  IN-AP      AP       Southern  Amaravati
# 2  Arunachal Pradesh  IN-AR      AR  North-Eastern   Itanagar
# 3              Assam  IN-AS      AS  North-Eastern     Dispur
# 4              Bihar  IN-BR      BR        Eastern      Patna
# 5       Chhattisgarh  IN-CG      CG        Central     Raipur
#
# 0            Statehood Population    Area Official Language
# 1  1956-11-01 00:00:00   49506799  162975            Telugu
# 2  1987-02-20 00:00:00    1383727   83743           English
# 3  1950-01-26 00:00:00   31205576   78438    Assamese, Boro
# 4  1950-01-26 00:00:00  104099452   94163             Hindi
# 5  2000-11-01 00:00:00   25545198  135194             Hindi

# %%
df3 = pd.read_excel('/content/drive/MyDrive/Data Source/india_state_ut.xlsx', sheet_name="UT")
df3.head()
# Out:
#                             Union Territory Unnamed: 1    Unnamed: 2  \
# 0                                     State        ISO  Vehicle code
# 1               Andaman and Nicobar Islands      IN-AN            AN
# 2                                Chandigarh      IN-CH            CH
# 3  Dadra and Nagar Haveli and Daman and Diu      IN-DH            DD
# 4                                     Delhi      IN-DL            DL
#
#   Unnamed: 3        Unnamed: 4           Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# 0       Zone           Capital          Established  Population       Area
# 1    Eastern  Sri Vijaya Puram  1956-11-01 00:00:00      380581       8249
# 2   Northern        Chandigarh  1966-11-01 00:00:00     1055450        114
# 3    Western             Daman  2020-01-26 00:00:00      587106        603
# 4   Northern         New Delhi  1956-11-01 00:00:00    16787941       1484
#
#            Unnamed: 8       Unnamed: 9
# 0  Official languages  Additional Info
# ...

# %%
df3.columns = df3.iloc[0]
df3 = df3[1:]
df3 = df3.drop('Additional Info', axis=1)
df3.head()
# Out:
# 0                                     State    ISO Vehicle code      Zone  \
# 1               Andaman and Nicobar Islands  IN-AN           AN   Eastern
# 2                                Chandigarh  IN-CH           CH  Northern
# 3  Dadra and Nagar Haveli and Daman and Diu  IN-DH           DD   Western
# 4                                     Delhi  IN-DL           DL  Northern
# 5                         Jammu and Kashmir  IN-JK           JK  Northern
#
# 0                            Capital          Established Population   Area  \
# 1                   Sri Vijaya Puram  1956-11-01 00:00:00     380581   8249
# 2                         Chandigarh  1966-11-01 00:00:00    1055450    114
# 3                              Daman  2020-01-26 00:00:00     587106    603
# 4                          New Delhi  1956-11-01 00:00:00   16787941   1484
# 5  Srinagar (Summer), Jammu (Winter)  2019-10-31 00:00:00   12258433  42241
#
# 0                     Official languages
# ...

# %%
df3 = df3.rename(columns={df3.columns[0]: 'UT'})
df3.head()
# Out:
# 0                                        UT    ISO Vehicle code      Zone  \
# 1               Andaman and Nicobar Islands  IN-AN           AN   Eastern
# 2                                Chandigarh  IN-CH           CH  Northern
# 3  Dadra and Nagar Haveli and Daman and Diu  IN-DH           DD   Western
# 4                                     Delhi  IN-DL           DL  Northern
# 5                         Jammu and Kashmir  IN-JK           JK  Northern
#
# 0                            Capital          Established Population   Area  \
# 1                   Sri Vijaya Puram  1956-11-01 00:00:00     380581   8249
# 2                         Chandigarh  1966-11-01 00:00:00    1055450    114
# 3                              Daman  2020-01-26 00:00:00     587106    603
# 4                          New Delhi  1956-11-01 00:00:00   16787941   1484
# 5  Srinagar (Summer), Jammu (Winter)  2019-10-31 00:00:00   12258433  42241
#
# 0                     Official languages
# ...

# %% [markdown]
# ***Extracting Data From a CSV File***

# %%
df4 = pd.read_csv('/content/drive/MyDrive/Data Source/cars.csv')
df4.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
df4.shape
# Out:
# (8128, 5)

# %%
df4[df4.duplicated()]
# Out:
#         brand  km_driven    fuel         owner  selling_price
# 291   Hyundai      35000  Petrol   First Owner         450000
# 296    Maruti      50000  Petrol  Second Owner         330000
# 370    Jaguar       9000  Diesel   First Owner        2625000
# 371     Lexus      20000  Petrol   First Owner        5150000
# 372    Jaguar      45000  Diesel   First Owner        3200000
# ...       ...        ...     ...           ...            ...
# 8115   Maruti     120000  Petrol   First Owner          40000
# 8117   Maruti      50000  Diesel   First Owner         625000
# 8118  Hyundai      25000  Petrol   First Owner         380000
# 8126     Tata      25000  Diesel   First Owner         290000
# 8127     Tata      25000  Diesel   First Owner         290000
#
# [1678 rows x 5 columns]

# %%
len(df4[df4.duplicated()])
# Out:
# 1678

# %%
df4 = df4.drop_duplicates()
df4.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %% [markdown]
# ***Extracting Data From a TSV File***

# %%
df5 = pd.read_csv('/content/drive/MyDrive/Data Source/people_data.tsv', sep="\t")
df5.head()
# Out:
#       name  age           city
# 0     John   30       New York
# 1     Jane   25         London
# 2    Alice   28          Paris
# 3      Bob   35         Sydney
# 4  Charlie   40  San Francisco

# %% [markdown]
# ***Extracting Data From a Text File***

# %%
df6 = pd.read_csv("/content/drive/MyDrive/Data Source/country_population.txt", sep="\t")
df6
# Out:
#           country  rank      area  landAreaKm cca2 cca3  netChange  \
# 0           India     1   3287590   2973190.0   IN  IND     0.4184
# 1           China     2   9706961   9424702.9   CN  CHN    -0.0113
# 2   United States     3   9372610   9147420.0   US  USA     0.0581
# 3       Indonesia     4   1904569   1877519.0   ID  IDN     0.0727
# 4        Pakistan     5    881912    770880.0   PK  PAK     0.1495
# 5         Nigeria     6    923768    910770.0   NG  NGA     0.1680
# 6          Brazil     7   8515767   8358140.0   BR  BRA     0.0393
# 7      Bangladesh     8    147570    130170.0   BD  BGD     0.0557
# 8          Russia     9  17098242  16376870.0   RU  RUS    -0.0158
# 9          Mexico    10   1964375   1943950.0   MX  MEX     0.0299
# 10       Ethiopia    11   1104300   1128571.3   ET  ETH     0.1008
#
#     growthRate  worldPercentage    density  densityMi  place     pop2023
# 0       0.0081           0.1785   480.5033  1244.5036    356  1428627663
# ...
