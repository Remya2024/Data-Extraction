# %% [markdown]
# # **Working With Semi Structured Data**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ***Extracting Data From an XML File***

# %%
import xml.etree.ElementTree as ET
import pandas as pd

# Parse the XML file
tree = ET.parse('/content/drive/My Drive/Data Source/books.xml')
root = tree.getroot()

# Extract book data
books = []
for book in root.findall('book'):
    book_data = {
        'id': book.get('id'),
        'author': book.find('author').text,
        'title': book.find('title').text,
        'genre': book.find('genre').text,
        'price': float(book.find('price').text),
        'publish_date': book.find('publish_date').text,
        'description': book.find('description').text.strip()
    }
    books.append(book_data)

# Create a DataFrame
df1 = pd.DataFrame(books)

# Display the DataFrame
df1
# Out:
#        id                author                                   title  \
# 0   bk101  Gambardella, Matthew                   XML Developer's Guide
# 1   bk102            Ralls, Kim                           Midnight Rain
# 2   bk103           Corets, Eva                         Maeve Ascendant
# 3   bk104           Corets, Eva                         Oberon's Legacy
# 4   bk105           Corets, Eva                      The Sundered Grail
# 5   bk106      Randall, Cynthia                             Lover Birds
# 6   bk107        Thurman, Paula                           Splish Splash
# 7   bk108         Knorr, Stefan                         Creepy Crawlies
# 8   bk109          Kress, Peter                            Paradox Lost
# 9   bk110          O'Brien, Tim   Microsoft .NET: The Programming Bible
# 10  bk111          O'Brien, Tim           MSXML3: A Comprehensive Guide
# 11  bk112           Galos, Mike  Visual Studio 7: A Comprehensive Guide
#
#               genre  price publish_date  \
# 0          Computer  44.95   2000-10-01
# 1           Fantasy   5.95   2000-12-16
# 2           Fantasy   5.95   2000-11-17
# 3           Fantasy   5.95   2001-03-10
# 4           Fantasy   5.95   2001-09-10
# 5           Romance   4.95   2000-09-02
# 6           Romance   4.95   2000-11-02
# 7            Horror   4.95   2000-12-06
# 8   Science Fiction   6.95   2000-11-02
# 9          Computer  36.95   2000-12-09
# 10         Computer  36.95   2000-12-01
# 11         Computer  49.95   2001-04-16
#
#                                           description
# 0   An in-depth look at creating applications \n  ...
# 1   A former architect battles corporate zombies, ...
# 2   After the collapse of a nanotechnology \n     ...
# 3   In post-apocalypse England, the mysterious \n ...
# 4   The two daughters of Maeve, half-sisters, \n  ...
# 5   When Carla meets Paul at an ornithology \n    ...
# 6   A deep sea diver finds true love twenty \n    ...
# 7   An anthology of horror stories about roaches,\...
# 8   After an inadvertant trip through a Heisenberg...
# 9   Microsoft's .NET initiative is explored in \n ...
# 10  The Microsoft MSXML3 parser is covered in \n  ...
# 11  Microsoft Visual Studio 7 is explored in depth...

# %% [markdown]
# ***Extracting Data From a json File***

# %%
import pandas as pd
import json

# Load the JSON file
file_path = '/content/drive/My Drive/Data Source/countries-table.json'
with open(file_path, 'r') as file:
    data = json.load(file)

# Convert the JSON data into a DataFrame
df2 = pd.DataFrame(data)
df2
# Out:
#      place      pop1980       pop2000       pop2010       pop2022  \
# 0      356  696828385.0  1.059634e+09  1.240614e+09  1.417173e+09
# 1      156  982372466.0  1.264099e+09  1.348191e+09  1.425887e+09
# 2      840  223140018.0  2.823986e+08  3.111828e+08  3.382899e+08
# 3      360  148177096.0  2.140724e+08  2.440162e+08  2.755013e+08
# 4      586   80624057.0  1.543699e+08  1.944545e+08  2.358249e+08
# ..     ...          ...           ...           ...           ...
# 229    500      11452.0  5.138000e+03  4.938000e+03  4.390000e+03
# 230    238       2240.0  3.080000e+03  3.187000e+03  3.780000e+03
# 231    570       3637.0  2.074000e+03  1.812000e+03  1.934000e+03
# 232    772       1647.0  1.666000e+03  1.367000e+03  1.871000e+03
# 233    336        733.0  6.510000e+02  5.960000e+02  5.100000e+02
#
#           pop2023       pop2030       pop2050           country        area  \
# 0    1.428628e+09  1.514994e+09  1.670491e+09             India  3287590.00
# 1    1.425671e+09  1.415606e+09  1.312636e+09             China  9706961.00
# 2    3.399966e+08  3.521623e+08  3.753920e+08     United States  9372610.00
# 3    2.775341e+08  2.921501e+08  3.172252e+08         Indonesia  1904569.00
# 4    2.404857e+08  2.740298e+08  3.678085e+08          Pakistan   881912.00
# ..            ...           ...           ...               ...         ...
# 229  4.386000e+03  4.301000e+03  3.781000e+03        Montserrat      102.00
# 230  3.791000e+03  3.869000e+03  3.779000e+03  Falkland Islands    12173.00
# 231  1.935000e+03  1.948000e+03  2.096000e+03              Niue      261.00
# 232  1.893000e+03  2.046000e+03  2.430000e+03           Tokelau       12.00
# 233  5.180000e+02  5.610000e+02  7.310000e+02      Vatican City        0.44
#
#      landAreaKm cca2 cca3  netChange  growthRate  worldPercentage    density  \
# 0    2973190.00   IN  IND     0.4184      0.0081           0.1785   480.5033
# 1    9424702.90   CN  CHN    -0.0113     -0.0002           0.1781   151.2696
# 2    9147420.00   US  USA     0.0581      0.0050           0.0425    37.1686
# 3    1877519.00   ID  IDN     0.0727      0.0074           0.0347   147.8196
# 4     770880.00   PK  PAK     0.1495      0.0198           0.0300   311.9625
# ..          ...  ...  ...        ...         ...              ...        ...
# 229      102.00   MS  MSR        NaN     -0.0009              NaN    43.0000
# 230    12173.00   FK  FLK        NaN      0.0029              NaN     0.3114
# 231      261.00   NU  NIU     0.0000      0.0005              NaN     7.4138
# 232       10.00   TK  TKL        NaN      0.0118              NaN   189.3000
# 233        0.44   VA  VAT        NaN      0.0157              NaN  1177.2727
#
#      densityMi  rank
# 0    1244.5036     1
# 1     391.7884     2
# 2      96.2666     3
# 3     382.8528     4
# 4     807.9829     5
# ..         ...   ...
# 229   111.3700   230
# 230     0.8066   231
# 231    19.2017   232
# 232   490.2870   233
# 233  3049.1364   234
#
# [234 rows x 19 columns]

# %% [markdown]
# ***Extracting Data From a yaml File***

# %%
import pandas as pd
import yaml

df3 = pd.DataFrame(yaml.safe_load(open("/content/drive/MyDrive/Data Source/ucm_2025.yaml")))
df3
# Out:
#                          Minister    Party  \
# 0                   Narendra Modi      BJP
# 1                   Narendra Modi      BJP
# 2                   Narendra Modi      BJP
# 3                   Narendra Modi      BJP
# 4                   Rajnath Singh      BJP
# 5                       Amit Shah      BJP
# 6                       Amit Shah      BJP
# 7                   Nitin Gadkari      BJP
# 8             Jagat Prakash Nadda      BJP
# 9             Jagat Prakash Nadda      BJP
# 10          Shivraj Singh Chouhan      BJP
# 11          Shivraj Singh Chouhan      BJP
# 12             Nirmala Sitharaman      BJP
# 13             Nirmala Sitharaman      BJP
# 14                  S. Jaishankar      BJP
# 15            Manohar Lal Khattar      BJP
# 16              H. D. Kumaraswamy    JD(S)
# 17              H. D. Kumaraswamy    JD(S)
# 18                   Piyush Goyal      BJP
# 19             Dharmendra Pradhan      BJP
# 20               Jitan Ram Manjhi   HAM(S)
# 21                    Lalan Singh    JD(U)
# 22             Sarbananda Sonowal      BJP
# 23          Virendra Kumar Khatik      BJP
# 24  Kinjarapu Ram Mohan Naidu[10]      TDP
# 25                  Prahlad Joshi      BJP
# 26                  Prahlad Joshi      BJP
# 27                      Jual Oram      BJP
# 28                  Giriraj Singh      BJP
# 29               Ashwini Vaishnaw      BJP
# 30               Ashwini Vaishnaw      BJP
# 31           Jyotiraditya Scindia      BJP
# 32           Jyotiraditya Scindia      BJP
# 33                Bhupender Yadav      BJP
# 34       Gajendra Singh Shekhawat      BJP
# 35       Gajendra Singh Shekhawat      BJP
# 36                  Annpurna Devi      BJP
# 37                   Kiren Rijiju      BJP
# 38             Hardeep Singh Puri      BJP
# 39           Mansukh L. Mandaviya      BJP
# 40           Mansukh L. Mandaviya      BJP
# 41                G. Kishan Reddy      BJP
# 42                G. Kishan Reddy      BJP
# 43                  Chirag Paswan  LJP(RV)
# 44                    C. R. Patil      BJP
#
#                                             Portfolio
# 0                                      Prime Minister
# 1   Minister of Personnel, Public Grievances and P...
# 2                         Department of Atomic Energy
# 3                                 Department of Space
# 4                                 Minister of Defence
# 5                            Minister of Home Affairs
# 6                            Minister of Co-operation
# 7             Minister of Road Transport and Highways
# 8               Minister of Health and Family Welfare
# 9               Minister of Chemicals and Fertilizers
# 10        Minister of Agriculture and Farmers Welfare
# 11                      Minister of Rural Development
# 12                                Minister of Finance
# 13                      Minister of Corporate Affairs
# 14                       Minister of External Affairs
# 15  Minister of Power&Minister of Housing and Urba...
# 16                       Minister of Heavy Industries
# 17                                  Minister of Steel
# 18                  Minister of Commerce and Industry
# 19                              Minister of Education
# 20    Minister of Micro, Small and Medium Enterprises
# 21                         Minister of Panchayati Raj
# 22          Minister of Ports, Shipping and Waterways
# 23         Minister of Social Justice and Empowerment
# 24                         Minister of Civil Aviation
# 25  Minister of Consumer Affairs, Food and Public ...
# 26               Minister of New and Renewable Energy
# 27                         Minister of Tribal Affairs
# 28                               Minister of Textiles
# 29           Minister of Information and Broadcasting
# 30                               Minister of Railways
# 31    Minister of Development of North Eastern Region
# 32                         Minister of Communications
# 33  Minister of Environment, Forest and Climate Ch...
# 34                                Minister of Culture
# 35                                Minister of Tourism
# 36            Minister of Women and Child Development
# 37                  Minister of Parliamentary Affairs
# 38              Minister of Petroleum and Natural Gas
# 39                  Minister of Labour and Employment
# 40               Minister of Youth Affairs and Sports
# 41                                   Minister of Coal
# 42                                  Minister of Mines
# 43             Minister of Food Processing Industries
# 44                             Minister of Jal Shakti
